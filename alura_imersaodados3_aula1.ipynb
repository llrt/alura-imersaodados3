# %% [markdown]
# <a href="https://colab.research.google.com/github/llrt/alura-imersaodados3/blob/main/alura_imersaodados3_aula1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Imersão Dados da Alura - Aula 1
#
# Análise exploratória de dados em cima de problema de _drug discovery_

# %% [markdown]
# ## Importação de bibliotecas e leitura de base dados

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all" # config para printar todos os statements, nao apenas o último

import pandas as pd 

pd.set_option('display.max_rows', 300) # setar nr de linhas mostradas
pd.set_option('display.max_columns', 50) # setar nr de colunas mostradas

# %%
# Ler base de dados de interesse
dados = pd.read_csv("https://github.com/llrt/alura-imersaodados3/blob/main/dados/dados_experimentos.zip?raw=true", 
            compression="zip") # como o arquivo é um CSV zipado, utilizar opção para tratamento automático da compressão

# %% [markdown]
# ## Dados gerais da base de dados

# %%
dados.shape # dimensões da base de dados (nr de linhas, nr de colunas)
# Out:
# (23814, 877)

# %%
dados.info() # dados gerais das colunas
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23814 entries, 0 to 23813
# Columns: 877 entries, id to c-99
# dtypes: float64(872), int64(1), object(4)
# memory usage: 159.3+ MB

# %%
dados.head(n=6) # 6 primeiras linhas da base
dados.tail(n=6) # 6 últimas linhas da base
# Out:
#              id tratamento  tempo dose      droga     g-0     g-1     g-2  \
# 0  id_000644bb2  com_droga     24   D1  b68db1d53  1.0620  0.5577 -0.2479
# 1  id_000779bfc  com_droga     72   D1  df89a8e5a  0.0743  0.4087  0.2991
# 2  id_000a6266a  com_droga     48   D1  18bb41b2c  0.6280  0.5817  1.5540
# 3  id_0015fd391  com_droga     48   D1  8c7f86626 -0.5138 -0.2491 -0.2656
# 4  id_001626bd3  com_droga     72   D2  7cbed3131 -0.3254 -0.4009  0.9700
# 5  id_001762a82  com_droga     24   D1  e06749542 -0.6111  0.2941 -0.9901
#
#       g-3     g-4     g-5     g-6     g-7     g-8     g-9    g-10    g-11  \
# 0 -0.6208 -0.1944 -1.0120 -1.0220 -0.0326  0.5548 -0.0921  1.1830  0.1530
# 1  0.0604  1.0190  0.5207  0.2341  0.3372 -0.4047  0.8507 -1.1520 -0.4201
# 2 -0.0764 -0.0323  1.2390  0.1715  0.2155  0.0065  1.2300 -0.4797 -0.5631
# 3  0.5288  4.0620 -0.8095 -1.9590  0.1792 -0.1321 -1.0600 -0.8269 -0.3584
# 4  0.6919  1.4180 -0.8244 -0.2800 -0.1498 -0.8789  0.8630 -0.2219 -0.5121
# 5  0.2277  1.2810  0.5203  0.0543 -0.2225 -0.1586  0.4289  0.0361  0.3543
#
#      g-12    g-13    g-14    g-15    g-16    g-17    g-18    g-19  ...  \
# 0  0.5574 -0.4015  0.1789 -0.6528 -0.7969  0.6342  0.1778 -0.3694  ...
# 1 -0.0958  0.4590  0.0803  0.2250  0.5293  0.2839 -0.3494  0.2883  ...
# 2 -0.0366 -1.8300  0.6057 -0.3278  0.6042 -0.3075 -0.1147 -0.0570  ...
# 3 -0.8511 -0.5844 -2.5690  0.8183 -0.0532 -0.8554  0.1160 -2.3520  ...
# 4 -0.9577  1.1750  0.2042  0.1970  0.1244 -1.7090 -0.3543 -0.5160  ...
# 5  0.8310 -0.9129  0.7677 -0.2512  0.7087  0.0481 -0.4486  1.2570  ...
#
#      c-75    c-76    c-77    c-78    c-79    c-80    c-81    c-82    c-83  \
# 0  0.0495  0.4141  0.8432  0.6162 -0.7318  1.2120  0.6362 -0.4427  0.1288
# 1  0.7639  0.5499 -0.3322 -0.0977  0.4329 -0.2782  0.7827  0.5934  0.3402
# 2  0.9760 -0.0427 -0.1235  0.0959  0.0690 -0.9416 -0.7548 -0.1109 -0.6272
# 3 -1.0810 -3.0520 -3.4470 -2.7740 -1.8460 -0.5568 -3.3960 -2.9510 -1.1550
# 4  0.4817  0.0587  0.5303  0.6376 -0.3966 -1.4950 -0.9625 -0.0541  0.6273
# 5  0.2152  1.6920 -0.2930  1.4590  1.0950  0.5854  1.7270  0.5580  1.3090
#
#      c-84    c-85    c-86    c-87    c-88    c-89    c-90    c-91    c-92  \
# 0  1.4840  0.1799  0.5367 -0.1111 -1.0120  0.6685  0.2862  0.2584  0.8076
# 1  0.1499  0.4420  0.9366  0.8193 -0.4236  0.3192 -0.4265  0.7543  0.4708
# 2  0.3019  0.1172  0.1093 -0.3113  0.3019 -0.0873 -0.7250 -0.6297  0.6103
# 3 -3.2620 -1.5390 -2.4600 -0.9417 -1.5550  0.2431 -2.0990 -0.6441 -5.6300
# 4  0.4563  0.0698  0.8134  0.1924  0.6054 -0.1824  0.0042  0.0048  0.6670
# 5  1.0100  0.6980  0.5455  1.0170  1.2910  1.5430  1.8390  1.1570 -1.0120
#
#      c-93    c-94    c-95    c-96    c-97    c-98    c-99
# 0  0.5523 -0.1912  0.6584 -0.3981  0.2139  0.3801  0.4176
# 0      0.1288  1.4840  0.1799  0.5367 -0.1111 -1.0120  0.6685  0.2862  0.2584
# 1      0.3402  0.1499  0.4420  0.9366  0.8193 -0.4236  0.3192 -0.4265  0.7543
# 2     -0.6272  0.3019  0.1172  0.1093 -0.3113  0.3019 -0.0873 -0.7250 -0.6297
# 3     -1.1550 -3.2620 -1.5390 -2.4600 -0.9417 -1.5550  0.2431 -2.0990 -0.6441
# 4      0.6273  0.4563  0.0698  0.8134  0.1924  0.6054 -0.1824  0.0042  0.0048
# ...       ...     ...     ...     ...     ...     ...     ...     ...     ...
# 23809  1.1660  0.3329  0.2754  0.4108 -0.1252 -0.2340  0.2267  0.1969  0.0262
# 23810 -1.1080  0.4895 -0.2144  1.0960  0.3335  0.4444 -1.1130  0.4286  0.4426
# 23811  0.0708  0.6169  0.2248  0.5994  0.2689  0.0305  1.2320  0.5409  0.3755
# 23812 -0.0650  0.9038  0.2324  0.9676  1.0940  0.4290  0.5187 -0.1105  0.4258
# 23813 -2.1560 -2.4100 -1.8190 -3.3480 -0.1414 -2.6430 -2.5810 -3.3890 -1.7450
#
#          c-92    c-93    c-94    c-95    c-96    c-97    c-98    c-99
# 0      0.8076  0.5523 -0.1912  0.6584 -0.3981  0.2139  0.3801  0.4176
# 1      0.4708  0.0230  0.2957  0.4899  0.1522  0.1241  0.6077  0.7371
# 2      0.6103  0.0223 -1.3240 -0.3174 -0.6417 -0.2187 -1.4080  0.6931
# 3     -5.6300 -1.3780 -0.8632 -1.2880 -1.6210 -0.8784 -0.3876 -0.8154
# 4      0.6670  1.0690  0.5523 -0.3031  0.1094  0.2885 -0.3786  0.7125
# ...       ...     ...     ...     ...     ...     ...     ...     ...
# 23809 -0.8121  0.3434  0.5372 -0.3246  0.0631  0.9171  0.5258  0.4680
# 23810  0.0423 -0.3195 -0.8086 -0.9798 -0.2084 -0.1224 -0.2715  0.3689
# 23811  0.7343  0.2807  0.4116  0.6422  0.2256  0.7592  0.6656  0.3808
# 23812 -0.2012  0.1506  1.5230  0.7101  0.1732  0.7015 -0.6290  0.0740
# 23813 -6.6300 -4.0950 -7.3860 -1.4160 -3.5770 -0.4775 -2.1500 -4.2520
#
# [23814 rows x 877 columns]

# %% [markdown]
# ## Análise univariada (i.e. de cada coluna isolada)

# %% [markdown]
# ### Coluna _tratamento_

# %% [markdown]
# Quais são os valores únicos da coluna tratamento? Qual a sua semântica?

# %%
dados['tratamento'].value_counts() # quais valores únicos existem na coluna?
# Out:
# com_droga       21948
# com_controle     1866
# Name: tratamento, dtype: int64

# %%
dados['tratamento'].value_counts(normalize=True) # qual a proporção entre os valores únicos encontrados
# Out:
# com_droga       0.921643
# com_controle    0.078357
# Name: tratamento, dtype: float64

# %% [markdown]
# A coluna _tratamento_ indica se o experimento em questão se refere a um grupo de controle (_com_controle_ ) ou de teste (_com_droga_). Note que a proporcao é muito desbalanceada (92% com droga). Por quê?

# %%
# Out:
# com_droga       0.921643
# com_controle    0.078357
# Name: tratamento, dtype: float64

# %% [markdown]
# ### Coluna _droga_

# %% [markdown]
# A coluna droga identifica de maneira única a droga/fármaco (ou controle) testado naquele experimento. Quantas são as drogas testadas?

# %%
dados['droga'].value_counts()
# Out:
# cacb2b860    1866
# 87d714366     718
# 9f80f3f77     246
# 8b87a7a83     203
# 5628cb3ee     202
#              ...
# c5ffd58ca       1
# 0e6ee26ff       1
# 573c787a2       1
# 4055d26a8       1
# 82dcdb180       1
# Name: droga, Length: 3289, dtype: int64

# %% [markdown]
# Parecem muitas drogas! Na verdade não são fármacos finais, mas são compostos que estão sendo testados.

# %% [markdown]
# ## Conclusões
#
# * A base registra diversos experimentos com fármacos, num total de 23813 experimentos, com um total de 877 colunas de informações
# * Além de colunas de id do experimento (campo *id*), temos colunas que informam:
# ** Se se trata de experimento do grupo de controle (sem uso de fármaco ou placebo) ou com uso de fármaco - campo *tratamento*
# ** Qual o tempo de uso do fármaco - campo *tempo*
# ** O tipo de dose aplicada (D1 ou D2, a investigar o que significam) - campo *dose*
# ** O id da droga investigada - campo *droga*
# ** A expressão gênica naquele experimento - campos *g-\**
#
# ## Dúvidas
#
# * O que significam as doses D1 e D2? São doses de tamanhos diferentes?
# * Os campos *g-\** estão com dados normalizados?
# * O que são os campos *c-\** ?
